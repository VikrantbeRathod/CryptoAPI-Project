# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
#jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10 enter in cmd prompt for error
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'30',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '03285a3f-b72b-4298-8263-295be4fddcdd',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-09-23T18:11:03.221Z', 'error_code': 0, 'error_message': None, 'elapsed': 31, 'credit_count': 1, 'notice': None, 'total_count': 9113}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10476, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns',None)
df=pd.json_normalize(data['data'])
df['Timestamp']=pd.to_datetime('now')

# %%
df
# Out:
#        id              name symbol                  slug  num_market_pairs  \
# 0       1           Bitcoin    BTC               bitcoin             10476
# 1    1027          Ethereum    ETH              ethereum              7429
# 2     825       Tether USDt   USDT                tether             62721
# 3    1839               BNB    BNB                   bnb              1634
# 4      52               XRP    XRP                   xrp              1097
# 5    3408          USD Coin   USDC              usd-coin             14204
# 6      74          Dogecoin   DOGE              dogecoin               800
# 7    2010           Cardano    ADA               cardano               938
# 8    5426            Solana    SOL                solana               530
# 9   11419           Toncoin    TON               toncoin               150
# 10   1958              TRON    TRX                  tron               840
# ...

# %%
def api_runner():
    global df
    url='https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'30',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '03285a3f-b72b-4298-8263-295be4fddcdd',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    import pandas as pd
    df=pd.json_normalize(data['data'])
    df['Timestamp']=pd.to_datetime('now')
    df 

    if not os.path.isfile(r'D:\Analyst Project\API Project.csv'):
        df.to_csv(r'D:\Analyst Project\API Project.csv',header='column_names')
    else:
        df.to_csv(r'D:\Analyst Project\API Project.csv',mode='a',header=False)

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner Completed')
    sleep(60)
exit()
# Out:
# {'status': {'timestamp': '2023-09-23T18:11:13.796Z', 'error_code': 0, 'error_message': None, 'elapsed': 21, 'credit_count': 1, 'notice': None, 'total_count': 9113}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10476, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
df7=pd.read_csv(r'D:\Analyst Project\API Project.csv')
df7
# Out:
#     Unnamed: 0    id              name symbol              slug  \
# 0            0     1           Bitcoin    BTC           bitcoin
# 1            1   825       Tether USDt   USDT            tether
# 2            2    52               XRP    XRP               xrp
# 3            3    74          Dogecoin   DOGE          dogecoin
# 4            4     2          Litecoin    LTC          litecoin
# ..         ...   ...               ...    ...               ...
# 92          25  3897               OKB    OKB               okb
# 93          26  7083           Uniswap    UNI           uniswap
# 94          27  4687              BUSD   BUSD       binance-usd
# 95          28  1321  Ethereum Classic    ETC  ethereum-classic
# 96          29  4642            Hedera   HBAR            hedera
#
#     num_market_pairs                date_added  \
# 0              10476  2010-07-13T00:00:00.000Z
# 1              62721  2015-02-25T00:00:00.000Z
# 2               1097  2013-08-04T00:00:00.000Z
# ...

# %%
pd.set_option('display.float_format',lambda x: '%.5f' %x)

# %%
 df
# Out:
#        id              name symbol                  slug  num_market_pairs  \
# 0       1           Bitcoin    BTC               bitcoin             10476
# 1    1027          Ethereum    ETH              ethereum              7429
# 2     825       Tether USDt   USDT                tether             62721
# 3    1839               BNB    BNB                   bnb              1634
# 4      52               XRP    XRP                   xrp              1097
# 5    3408          USD Coin   USDC              usd-coin             14204
# 6      74          Dogecoin   DOGE              dogecoin               800
# 7    2010           Cardano    ADA               cardano               938
# 8    5426            Solana    SOL                solana               530
# 9   11419           Toncoin    TON               toncoin               150
# 10   1958              TRON    TRX                  tron               840
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#                   quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                               0.12371                       0.28231
# Ethereum                              0.05076                       0.20354
# Tether USDt                           0.00387                       0.01493
# BNB                                  -0.03079                       0.00832
# XRP                                   0.06627                      -0.79548
# USD Coin                             -0.00321                       0.00604
# Dogecoin                              0.04408                       0.40108
# Cardano                               0.31543                       0.97419
# Solana                                0.15893                       0.50306
# Toncoin                              -0.35828                       0.03983
# TRON                                  0.05547                       0.11562
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin  quote.USD.percent_change_1h      0.12371
#          quote.USD.percent_change_24h     0.28231
#          quote.USD.percent_change_7d      0.07457
#          quote.USD.percent_change_30d     2.32320
#          quote.USD.percent_change_60d    -9.07293
#                                            ...
# Hedera   quote.USD.percent_change_24h     3.54142
#          quote.USD.percent_change_7d      1.29060
#          quote.USD.percent_change_30d   -13.07585
#          quote.USD.percent_change_60d    -0.72697
#          quote.USD.percent_change_90d    -0.52134
# Length: 180, dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                         values
# name
# Bitcoin quote.USD.percent_change_1h    0.12371
#         quote.USD.percent_change_24h   0.28231
#         quote.USD.percent_change_7d    0.07457
#         quote.USD.percent_change_30d   2.32320
#         quote.USD.percent_change_60d  -9.07293
# ...                                        ...
# Hedera  quote.USD.percent_change_24h   3.54142
#         quote.USD.percent_change_7d    1.29060
#         quote.USD.percent_change_30d -13.07585
#         quote.USD.percent_change_60d  -0.72697
#         quote.USD.percent_change_90d  -0.52134
#
# [180 rows x 1 columns]

# %%
df5.count()
# Out:
# values    180
# dtype: int64

# %%
index = pd.Index(range(180))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.reset_index()
df6
# Out:
#         name                       level_1    values
# 0    Bitcoin   quote.USD.percent_change_1h   0.12371
# 1    Bitcoin  quote.USD.percent_change_24h   0.28231
# 2    Bitcoin   quote.USD.percent_change_7d   0.07457
# 3    Bitcoin  quote.USD.percent_change_30d   2.32320
# 4    Bitcoin  quote.USD.percent_change_60d  -9.07293
# ..       ...                           ...       ...
# 175   Hedera  quote.USD.percent_change_24h   3.54142
# 176   Hedera   quote.USD.percent_change_7d   1.29060
# 177   Hedera  quote.USD.percent_change_30d -13.07585
# 178   Hedera  quote.USD.percent_change_60d  -0.72697
# 179   Hedera  quote.USD.percent_change_90d  -0.52134
#
# [180 rows x 3 columns]

# %%
df7 = df6.rename(columns={'level_1':'percent_change'})
df7
# Out:
#         name                percent_change    values
# 0    Bitcoin   quote.USD.percent_change_1h   0.12371
# 1    Bitcoin  quote.USD.percent_change_24h   0.28231
# 2    Bitcoin   quote.USD.percent_change_7d   0.07457
# 3    Bitcoin  quote.USD.percent_change_30d   2.32320
# 4    Bitcoin  quote.USD.percent_change_60d  -9.07293
# ..       ...                           ...       ...
# 175   Hedera  quote.USD.percent_change_24h   3.54142
# 176   Hedera   quote.USD.percent_change_7d   1.29060
# 177   Hedera  quote.USD.percent_change_30d -13.07585
# 178   Hedera  quote.USD.percent_change_60d  -0.72697
# 179   Hedera  quote.USD.percent_change_90d  -0.52134
#
# [180 rows x 3 columns]

# %%
df7['percent_change']= df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#         name percent_change    values
# 0    Bitcoin             1h   0.12371
# 1    Bitcoin            24h   0.28231
# 2    Bitcoin             7d   0.07457
# 3    Bitcoin            30d   2.32320
# 4    Bitcoin            60d  -9.07293
# ..       ...            ...       ...
# 175   Hedera            24h   3.54142
# 176   Hedera             7d   1.29060
# 177   Hedera            30d -13.07585
# 178   Hedera            60d  -0.72697
# 179   Hedera            90d  -0.52134
#
# [180 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')
# Out:
# C:\Users\iamvr\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\iamvr\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\iamvr\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df10 = df[['name','quote.USD.price','Timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#       name  quote.USD.price                  Timestamp
# 0  Bitcoin      26624.69448 2023-09-23 23:42:14.835651

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='Timestamp', y='quote.USD.price', data = df10)
# Out:
# C:\Users\iamvr\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\iamvr\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\iamvr\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
